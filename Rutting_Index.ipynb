# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-fc753941-2eed-4a3e-8a7a-806dbc6f65f2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fc753941-2eed-4a3e-8a7a-806dbc6f65f2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# {}

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from keras.models import load_model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Activation, Dropout
from tensorflow.keras.optimizers import Adam, SGD,Adagrad
from tensorflow.keras.losses import mean_absolute_error,mean_absolute_percentage_error
from tensorflow.keras.callbacks import EarlyStopping,ModelCheckpoint
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('1.xlsx',sheet_name=2)

# %%
x = df.iloc[:,0:8]
y = df.iloc[:,8]

# %%
train_ind = int(0.72 * x.shape[0])
x_train = x[:train_ind].values
x_test = x[train_ind:].values
y_train = y[:train_ind].values
y_test = y[train_ind:].values
y_train = np.reshape(y_train, newshape=(-1, 1))
y_test = np.reshape(y_test, newshape=(-1, 1))

# %%
# scalers
scaler_x = StandardScaler()
scaler_y = StandardScaler()
# scaling
x_train_sc = scaler_x.fit_transform(x_train)
x_test_sc = scaler_x.transform(x_test)
y_train_sc = scaler_y.fit_transform(y_train)
y_test_sc = scaler_y.transform(y_test)
x_train_sc.shape
# Out:
# (60, 8)

# %%
model = Sequential()
model.add(Dense(units=5, activation='tanh',input_dim=8))
model.add(Dense(units=5, activation='tanh',kernel_regularizer=tf.keras.regularizers.l2(0.001)))
model.add(Dense(units=5, activation='tanh',kernel_regularizer=tf.keras.regularizers.l2(0.001)))
model.add(Dense(units=1, activation='linear'))
adam = tf.keras.optimizers.Adam(learning_rate=0.001)
sgd = tf.keras.optimizers.SGD(learning_rate=0.001)
adagrds = tf.keras.optimizers.Adagrad(learning_rate=0.001)
model.compile(optimizer=adam, loss='mean_absolute_error')

# %%
filepath = 'bestmodel.h5'
checkpoint = ModelCheckpoint(filepath,monitor='loss',verbose=1,save_best_only=True,mode='min')
early_stop = EarlyStopping(monitor='val_loss',verbose=1,mode="min",restore_best_weights=True,patience=50)
callback_list = [checkpoint,early_stop]

# %%
hist = model.fit(x_train_sc, y_train_sc,validation_data=(x_test_sc,y_test_sc), epochs=1000,callbacks=callback_list)
# Out:
# Epoch 1/1000
# 2/2 [==============================] - 1s 410ms/step - loss: 0.7207 - val_loss: 0.7954
#
# Epoch 00001: loss improved from inf to 0.72482, saving model to bestmodel.h5
# Epoch 2/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.7002 - val_loss: 0.7967
#
# Epoch 00002: loss improved from 0.72482 to 0.71589, saving model to bestmodel.h5
# Epoch 3/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.7044 - val_loss: 0.7975
#
# Epoch 00003: loss improved from 0.71589 to 0.70874, saving model to bestmodel.h5
# Epoch 4/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6921 - val_loss: 0.7987
#
# Epoch 00004: loss improved from 0.70874 to 0.70196, saving model to bestmodel.h5
# Epoch 5/1000
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6965 - val_loss: 0.7998
#
# Epoch 00005: loss improved from 0.70196 to 0.69712, saving model to bestmodel.h5
# Epoch 6/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6855 - val_loss: 0.8007
#
# Epoch 00006: loss improved from 0.69712 to 0.69098, saving model to bestmodel.h5
# Epoch 7/1000
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6751 - val_loss: 0.8013
#
# Epoch 00007: loss improved from 0.69098 to 0.68557, saving model to bestmodel.h5
# Epoch 8/1000
# 2/2 [==============================] - 0s 34ms/step - loss: 0.7012 - val_loss: 0.8016
#
# Epoch 00008: loss improved from 0.68557 to 0.68270, saving model to bestmodel.h5
# Epoch 9/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6820 - val_loss: 0.8018
#
# Epoch 00009: loss improved from 0.68270 to 0.67844, saving model to bestmodel.h5
# Epoch 10/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6975 - val_loss: 0.8016
#
# Epoch 00010: loss improved from 0.67844 to 0.67482, saving model to bestmodel.h5
# Epoch 11/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7079 - val_loss: 0.8012
#
# Epoch 00011: loss improved from 0.67482 to 0.67161, saving model to bestmodel.h5
# Epoch 12/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6794 - val_loss: 0.8009
#
# Epoch 00012: loss improved from 0.67161 to 0.66799, saving model to bestmodel.h5
# Epoch 13/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6642 - val_loss: 0.8002
#
# Epoch 00013: loss improved from 0.66799 to 0.66566, saving model to bestmodel.h5
# Epoch 14/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.7004 - val_loss: 0.7993
#
# Epoch 00014: loss improved from 0.66566 to 0.66531, saving model to bestmodel.h5
# Epoch 15/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6402 - val_loss: 0.7983
#
# Epoch 00015: loss improved from 0.66531 to 0.66352, saving model to bestmodel.h5
# Epoch 16/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6055 - val_loss: 0.7973
#
# Epoch 00016: loss improved from 0.66352 to 0.66203, saving model to bestmodel.h5
# Epoch 17/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6117 - val_loss: 0.7961
#
# Epoch 00017: loss improved from 0.66203 to 0.65999, saving model to bestmodel.h5
# Epoch 18/1000
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6751 - val_loss: 0.7942
#
# Epoch 00018: loss improved from 0.65999 to 0.65836, saving model to bestmodel.h5
# Epoch 19/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6789 - val_loss: 0.7924
#
# Epoch 00019: loss improved from 0.65836 to 0.65693, saving model to bestmodel.h5
# Epoch 20/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6599 - val_loss: 0.7905
#
# Epoch 00020: loss improved from 0.65693 to 0.65488, saving model to bestmodel.h5
# Epoch 21/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6461 - val_loss: 0.7884
#
# Epoch 00021: loss improved from 0.65488 to 0.65288, saving model to bestmodel.h5
# Epoch 22/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6739 - val_loss: 0.7864
#
# Epoch 00022: loss improved from 0.65288 to 0.65126, saving model to bestmodel.h5
# Epoch 23/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6429 - val_loss: 0.7845
#
# Epoch 00023: loss improved from 0.65126 to 0.64975, saving model to bestmodel.h5
# Epoch 24/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6651 - val_loss: 0.7828
#
# Epoch 00024: loss improved from 0.64975 to 0.64827, saving model to bestmodel.h5
# Epoch 25/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6556 - val_loss: 0.7813
#
# Epoch 00025: loss improved from 0.64827 to 0.64676, saving model to bestmodel.h5
# Epoch 26/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6045 - val_loss: 0.7802
#
# Epoch 00026: loss improved from 0.64676 to 0.64510, saving model to bestmodel.h5
# Epoch 27/1000
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6561 - val_loss: 0.7791
#
# Epoch 00027: loss improved from 0.64510 to 0.64378, saving model to bestmodel.h5
# Epoch 28/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6387 - val_loss: 0.7780
#
# Epoch 00028: loss improved from 0.64378 to 0.64240, saving model to bestmodel.h5
# Epoch 29/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6535 - val_loss: 0.7773
#
# Epoch 00029: loss improved from 0.64240 to 0.64165, saving model to bestmodel.h5
# Epoch 30/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6198 - val_loss: 0.7759
#
# Epoch 00030: loss improved from 0.64165 to 0.63985, saving model to bestmodel.h5
# Epoch 31/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6084 - val_loss: 0.7742
#
# Epoch 00031: loss improved from 0.63985 to 0.63853, saving model to bestmodel.h5
# Epoch 32/1000
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6153 - val_loss: 0.7721
#
# Epoch 00032: loss improved from 0.63853 to 0.63708, saving model to bestmodel.h5
# Epoch 33/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6488 - val_loss: 0.7703
#
# Epoch 00033: loss improved from 0.63708 to 0.63607, saving model to bestmodel.h5
# Epoch 34/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6186 - val_loss: 0.7690
#
# Epoch 00034: loss improved from 0.63607 to 0.63481, saving model to bestmodel.h5
# Epoch 35/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6389 - val_loss: 0.7676
#
# Epoch 00035: loss improved from 0.63481 to 0.63321, saving model to bestmodel.h5
# Epoch 36/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6701 - val_loss: 0.7665
#
# Epoch 00036: loss improved from 0.63321 to 0.63161, saving model to bestmodel.h5
# Epoch 37/1000
# 2/2 [==============================] - 0s 28ms/step - loss: 0.6241 - val_loss: 0.7656
#
# Epoch 00037: loss improved from 0.63161 to 0.63072, saving model to bestmodel.h5
# Epoch 38/1000
# 2/2 [==============================] - 0s 37ms/step - loss: 0.6665 - val_loss: 0.7646
#
# Epoch 00038: loss improved from 0.63072 to 0.62925, saving model to bestmodel.h5
# Epoch 39/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6591 - val_loss: 0.7633
#
# Epoch 00039: loss improved from 0.62925 to 0.62792, saving model to bestmodel.h5
# Epoch 40/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5794 - val_loss: 0.7623
#
# Epoch 00040: loss improved from 0.62792 to 0.62661, saving model to bestmodel.h5
# Epoch 41/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6720 - val_loss: 0.7606
#
# Epoch 00041: loss improved from 0.62661 to 0.62547, saving model to bestmodel.h5
# Epoch 42/1000
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6523 - val_loss: 0.7592
#
# Epoch 00042: loss improved from 0.62547 to 0.62397, saving model to bestmodel.h5
# Epoch 43/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6194 - val_loss: 0.7585
#
# Epoch 00043: loss improved from 0.62397 to 0.62305, saving model to bestmodel.h5
# Epoch 44/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6678 - val_loss: 0.7577
#
# Epoch 00044: loss improved from 0.62305 to 0.62138, saving model to bestmodel.h5
# Epoch 45/1000
# 2/2 [==============================] - 0s 34ms/step - loss: 0.6303 - val_loss: 0.7569
#
# Epoch 00045: loss improved from 0.62138 to 0.62052, saving model to bestmodel.h5
# Epoch 46/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.6432 - val_loss: 0.7567
#
# Epoch 00046: loss improved from 0.62052 to 0.61896, saving model to bestmodel.h5
# Epoch 47/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5863 - val_loss: 0.7564
#
# Epoch 00047: loss improved from 0.61896 to 0.61772, saving model to bestmodel.h5
# Epoch 48/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6247 - val_loss: 0.7558
#
# Epoch 00048: loss improved from 0.61772 to 0.61664, saving model to bestmodel.h5
# Epoch 49/1000
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6138 - val_loss: 0.7547
#
# Epoch 00049: loss improved from 0.61664 to 0.61534, saving model to bestmodel.h5
# Epoch 50/1000
# 2/2 [==============================] - 0s 36ms/step - loss: 0.6260 - val_loss: 0.7536
#
# Epoch 00050: loss improved from 0.61534 to 0.61400, saving model to bestmodel.h5
# Epoch 51/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6022 - val_loss: 0.7528
#
# Epoch 00051: loss improved from 0.61400 to 0.61271, saving model to bestmodel.h5
# Epoch 52/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5834 - val_loss: 0.7519
#
# Epoch 00052: loss improved from 0.61271 to 0.61172, saving model to bestmodel.h5
# Epoch 53/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.5973 - val_loss: 0.7509
#
# Epoch 00053: loss improved from 0.61172 to 0.61043, saving model to bestmodel.h5
# Epoch 54/1000
# 2/2 [==============================] - 0s 35ms/step - loss: 0.5654 - val_loss: 0.7499
#
# Epoch 00054: loss improved from 0.61043 to 0.60953, saving model to bestmodel.h5
# Epoch 55/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5792 - val_loss: 0.7486
#
# Epoch 00055: loss improved from 0.60953 to 0.60829, saving model to bestmodel.h5
# Epoch 56/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5895 - val_loss: 0.7469
#
# Epoch 00056: loss improved from 0.60829 to 0.60725, saving model to bestmodel.h5
# Epoch 57/1000
# 2/2 [==============================] - 0s 47ms/step - loss: 0.6171 - val_loss: 0.7448
#
# Epoch 00057: loss improved from 0.60725 to 0.60625, saving model to bestmodel.h5
# Epoch 58/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5660 - val_loss: 0.7427
#
# Epoch 00058: loss improved from 0.60625 to 0.60432, saving model to bestmodel.h5
# Epoch 59/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6500 - val_loss: 0.7405
#
# Epoch 00059: loss improved from 0.60432 to 0.60314, saving model to bestmodel.h5
# Epoch 60/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6420 - val_loss: 0.7382
#
# Epoch 00060: loss improved from 0.60314 to 0.60201, saving model to bestmodel.h5
# Epoch 61/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6254 - val_loss: 0.7362
#
# Epoch 00061: loss improved from 0.60201 to 0.60101, saving model to bestmodel.h5
# Epoch 62/1000
# 2/2 [==============================] - 0s 35ms/step - loss: 0.5750 - val_loss: 0.7353
#
# Epoch 00062: loss improved from 0.60101 to 0.59927, saving model to bestmodel.h5
# Epoch 63/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.5852 - val_loss: 0.7337
#
# Epoch 00063: loss improved from 0.59927 to 0.59803, saving model to bestmodel.h5
# Epoch 64/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.5988 - val_loss: 0.7321
#
# Epoch 00064: loss improved from 0.59803 to 0.59683, saving model to bestmodel.h5
# Epoch 65/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6165 - val_loss: 0.7300
#
# Epoch 00065: loss improved from 0.59683 to 0.59553, saving model to bestmodel.h5
# Epoch 66/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5893 - val_loss: 0.7284
#
# Epoch 00066: loss improved from 0.59553 to 0.59420, saving model to bestmodel.h5
# Epoch 67/1000
# 2/2 [==============================] - 0s 40ms/step - loss: 0.5599 - val_loss: 0.7264
#
# Epoch 00067: loss improved from 0.59420 to 0.59283, saving model to bestmodel.h5
# Epoch 68/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5817 - val_loss: 0.7243
#
# Epoch 00068: loss improved from 0.59283 to 0.59165, saving model to bestmodel.h5
# Epoch 69/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.6031 - val_loss: 0.7217
#
# Epoch 00069: loss improved from 0.59165 to 0.59044, saving model to bestmodel.h5
# Epoch 70/1000
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5610 - val_loss: 0.7200
#
# Epoch 00070: loss improved from 0.59044 to 0.58930, saving model to bestmodel.h5
# Epoch 71/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5630 - val_loss: 0.7186
#
# Epoch 00071: loss improved from 0.58930 to 0.58830, saving model to bestmodel.h5
# Epoch 72/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5797 - val_loss: 0.7175
#
# Epoch 00072: loss improved from 0.58830 to 0.58665, saving model to bestmodel.h5
# Epoch 73/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5747 - val_loss: 0.7164
#
# Epoch 00073: loss improved from 0.58665 to 0.58550, saving model to bestmodel.h5
# Epoch 74/1000
# 2/2 [==============================] - 0s 35ms/step - loss: 0.5862 - val_loss: 0.7155
#
# Epoch 00074: loss improved from 0.58550 to 0.58403, saving model to bestmodel.h5
# Epoch 75/1000
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5562 - val_loss: 0.7147
#
# Epoch 00075: loss improved from 0.58403 to 0.58323, saving model to bestmodel.h5
# Epoch 76/1000
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5640 - val_loss: 0.7132
#
# Epoch 00076: loss improved from 0.58323 to 0.58122, saving model to bestmodel.h5
# Epoch 77/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5688 - val_loss: 0.7115
#
# Epoch 00077: loss improved from 0.58122 to 0.57994, saving model to bestmodel.h5
# Epoch 78/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.5873 - val_loss: 0.7098
#
# Epoch 00078: loss improved from 0.57994 to 0.57823, saving model to bestmodel.h5
# Epoch 79/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5430 - val_loss: 0.7078
#
# Epoch 00079: loss improved from 0.57823 to 0.57710, saving model to bestmodel.h5
# Epoch 80/1000
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6156 - val_loss: 0.7056
#
# Epoch 00080: loss improved from 0.57710 to 0.57536, saving model to bestmodel.h5
# Epoch 81/1000
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5488 - val_loss: 0.7039
#
# Epoch 00081: loss improved from 0.57536 to 0.57398, saving model to bestmodel.h5
# Epoch 82/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5795 - val_loss: 0.7021
#
# Epoch 00082: loss improved from 0.57398 to 0.57244, saving model to bestmodel.h5
# Epoch 83/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6043 - val_loss: 0.6996
#
# Epoch 00083: loss improved from 0.57244 to 0.57114, saving model to bestmodel.h5
# Epoch 84/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.5773 - val_loss: 0.6972
#
# Epoch 00084: loss improved from 0.57114 to 0.56957, saving model to bestmodel.h5
# Epoch 85/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5548 - val_loss: 0.6950
#
# Epoch 00085: loss improved from 0.56957 to 0.56792, saving model to bestmodel.h5
# Epoch 86/1000
# 2/2 [==============================] - 0s 45ms/step - loss: 0.5321 - val_loss: 0.6932
#
# Epoch 00086: loss improved from 0.56792 to 0.56654, saving model to bestmodel.h5
# Epoch 87/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5564 - val_loss: 0.6916
#
# Epoch 00087: loss improved from 0.56654 to 0.56448, saving model to bestmodel.h5
# Epoch 88/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5614 - val_loss: 0.6895
#
# Epoch 00088: loss improved from 0.56448 to 0.56284, saving model to bestmodel.h5
# Epoch 89/1000
# 2/2 [==============================] - 0s 29ms/step - loss: 0.5993 - val_loss: 0.6877
#
# Epoch 00089: loss improved from 0.56284 to 0.56140, saving model to bestmodel.h5
# Epoch 90/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5633 - val_loss: 0.6852
#
# Epoch 00090: loss improved from 0.56140 to 0.56036, saving model to bestmodel.h5
# Epoch 91/1000
# 2/2 [==============================] - 0s 35ms/step - loss: 0.6015 - val_loss: 0.6831
#
# Epoch 00091: loss improved from 0.56036 to 0.55792, saving model to bestmodel.h5
# Epoch 92/1000
# 2/2 [==============================] - 0s 38ms/step - loss: 0.5025 - val_loss: 0.6813
#
# Epoch 00092: loss improved from 0.55792 to 0.55604, saving model to bestmodel.h5
# Epoch 93/1000
# 2/2 [==============================] - 0s 43ms/step - loss: 0.5452 - val_loss: 0.6796
#
# Epoch 00093: loss improved from 0.55604 to 0.55400, saving model to bestmodel.h5
# Epoch 94/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5673 - val_loss: 0.6774
#
# Epoch 00094: loss improved from 0.55400 to 0.55197, saving model to bestmodel.h5
# Epoch 95/1000
# 2/2 [==============================] - 0s 35ms/step - loss: 0.5257 - val_loss: 0.6755
#
# Epoch 00095: loss improved from 0.55197 to 0.55005, saving model to bestmodel.h5
# Epoch 96/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5283 - val_loss: 0.6734
#
# Epoch 00096: loss improved from 0.55005 to 0.54835, saving model to bestmodel.h5
# Epoch 97/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5690 - val_loss: 0.6714
#
# Epoch 00097: loss improved from 0.54835 to 0.54604, saving model to bestmodel.h5
# Epoch 98/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5496 - val_loss: 0.6696
#
# Epoch 00098: loss improved from 0.54604 to 0.54433, saving model to bestmodel.h5
# Epoch 99/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5417 - val_loss: 0.6681
#
# Epoch 00099: loss improved from 0.54433 to 0.54221, saving model to bestmodel.h5
# Epoch 100/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5402 - val_loss: 0.6660
#
# Epoch 00100: loss improved from 0.54221 to 0.54071, saving model to bestmodel.h5
# Epoch 101/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5205 - val_loss: 0.6645
#
# Epoch 00101: loss improved from 0.54071 to 0.53896, saving model to bestmodel.h5
# Epoch 102/1000
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5062 - val_loss: 0.6636
#
# Epoch 00102: loss improved from 0.53896 to 0.53675, saving model to bestmodel.h5
# Epoch 103/1000
# 2/2 [==============================] - 0s 38ms/step - loss: 0.5412 - val_loss: 0.6627
#
# Epoch 00103: loss improved from 0.53675 to 0.53541, saving model to bestmodel.h5
# Epoch 104/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5268 - val_loss: 0.6616
#
# Epoch 00104: loss improved from 0.53541 to 0.53369, saving model to bestmodel.h5
# Epoch 105/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5354 - val_loss: 0.6612
#
# Epoch 00105: loss improved from 0.53369 to 0.53189, saving model to bestmodel.h5
# Epoch 106/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5112 - val_loss: 0.6603
#
# Epoch 00106: loss improved from 0.53189 to 0.53066, saving model to bestmodel.h5
# Epoch 107/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4794 - val_loss: 0.6592
#
# Epoch 00107: loss improved from 0.53066 to 0.52848, saving model to bestmodel.h5
# Epoch 108/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5059 - val_loss: 0.6576
#
# Epoch 00108: loss improved from 0.52848 to 0.52747, saving model to bestmodel.h5
# Epoch 109/1000
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5702 - val_loss: 0.6563
#
# Epoch 00109: loss improved from 0.52747 to 0.52565, saving model to bestmodel.h5
# Epoch 110/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4862 - val_loss: 0.6556
#
# Epoch 00110: loss improved from 0.52565 to 0.52398, saving model to bestmodel.h5
# Epoch 111/1000
# 2/2 [==============================] - 0s 36ms/step - loss: 0.5154 - val_loss: 0.6554
#
# Epoch 00111: loss improved from 0.52398 to 0.52292, saving model to bestmodel.h5
# Epoch 112/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5122 - val_loss: 0.6553
#
# Epoch 00112: loss improved from 0.52292 to 0.52146, saving model to bestmodel.h5
# Epoch 113/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5095 - val_loss: 0.6559
#
# Epoch 00113: loss improved from 0.52146 to 0.51946, saving model to bestmodel.h5
# Epoch 114/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5157 - val_loss: 0.6562
#
# Epoch 00114: loss improved from 0.51946 to 0.51800, saving model to bestmodel.h5
# Epoch 115/1000
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5252 - val_loss: 0.6563
#
# Epoch 00115: loss improved from 0.51800 to 0.51686, saving model to bestmodel.h5
# Epoch 116/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5286 - val_loss: 0.6560
#
# Epoch 00116: loss improved from 0.51686 to 0.51600, saving model to bestmodel.h5
# Epoch 117/1000
# 2/2 [==============================] - 0s 39ms/step - loss: 0.5253 - val_loss: 0.6553
#
# Epoch 00117: loss improved from 0.51600 to 0.51520, saving model to bestmodel.h5
# Epoch 118/1000
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4774 - val_loss: 0.6556
#
# Epoch 00118: loss improved from 0.51520 to 0.51418, saving model to bestmodel.h5
# Epoch 119/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5176 - val_loss: 0.6550
#
# Epoch 00119: loss improved from 0.51418 to 0.51303, saving model to bestmodel.h5
# Epoch 120/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5668 - val_loss: 0.6548
#
# Epoch 00120: loss improved from 0.51303 to 0.51188, saving model to bestmodel.h5
# Epoch 121/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5223 - val_loss: 0.6543
#
# Epoch 00121: loss improved from 0.51188 to 0.51080, saving model to bestmodel.h5
# Epoch 122/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5166 - val_loss: 0.6538
#
# Epoch 00122: loss improved from 0.51080 to 0.50996, saving model to bestmodel.h5
# Epoch 123/1000
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4909 - val_loss: 0.6539
#
# Epoch 00123: loss improved from 0.50996 to 0.50874, saving model to bestmodel.h5
# Epoch 124/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5087 - val_loss: 0.6543
#
# Epoch 00124: loss improved from 0.50874 to 0.50799, saving model to bestmodel.h5
# Epoch 125/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4833 - val_loss: 0.6558
#
# Epoch 00125: loss improved from 0.50799 to 0.50712, saving model to bestmodel.h5
# Epoch 126/1000
# 2/2 [==============================] - 0s 38ms/step - loss: 0.5121 - val_loss: 0.6564
#
# Epoch 00126: loss improved from 0.50712 to 0.50562, saving model to bestmodel.h5
# Epoch 127/1000
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5405 - val_loss: 0.6569
#
# Epoch 00127: loss improved from 0.50562 to 0.50508, saving model to bestmodel.h5
# Epoch 128/1000
# 2/2 [==============================] - 0s 35ms/step - loss: 0.5162 - val_loss: 0.6579
#
# Epoch 00128: loss improved from 0.50508 to 0.50405, saving model to bestmodel.h5
# Epoch 129/1000
# 2/2 [==============================] - 0s 36ms/step - loss: 0.5410 - val_loss: 0.6581
#
# Epoch 00129: loss improved from 0.50405 to 0.50321, saving model to bestmodel.h5
# Epoch 130/1000
# 2/2 [==============================] - 0s 35ms/step - loss: 0.4754 - val_loss: 0.6575
#
# Epoch 00130: loss improved from 0.50321 to 0.50202, saving model to bestmodel.h5
# Epoch 131/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4899 - val_loss: 0.6572
#
# Epoch 00131: loss improved from 0.50202 to 0.50126, saving model to bestmodel.h5
# Epoch 132/1000
# 2/2 [==============================] - 0s 43ms/step - loss: 0.5050 - val_loss: 0.6584
#
# Epoch 00132: loss improved from 0.50126 to 0.50044, saving model to bestmodel.h5
# Epoch 133/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5292 - val_loss: 0.6598
#
# Epoch 00133: loss improved from 0.50044 to 0.49938, saving model to bestmodel.h5
# Epoch 134/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4747 - val_loss: 0.6614
#
# Epoch 00134: loss improved from 0.49938 to 0.49902, saving model to bestmodel.h5
# Epoch 135/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4804 - val_loss: 0.6619
#
# Epoch 00135: loss improved from 0.49902 to 0.49826, saving model to bestmodel.h5
# Epoch 136/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5033 - val_loss: 0.6617
#
# Epoch 00136: loss improved from 0.49826 to 0.49744, saving model to bestmodel.h5
# Epoch 137/1000
# 2/2 [==============================] - 0s 37ms/step - loss: 0.4584 - val_loss: 0.6610
#
# Epoch 00137: loss improved from 0.49744 to 0.49657, saving model to bestmodel.h5
# Epoch 138/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5136 - val_loss: 0.6606
#
# Epoch 00138: loss improved from 0.49657 to 0.49632, saving model to bestmodel.h5
# Epoch 139/1000
# 2/2 [==============================] - 0s 35ms/step - loss: 0.4729 - val_loss: 0.6610
#
# Epoch 00139: loss improved from 0.49632 to 0.49565, saving model to bestmodel.h5
# Epoch 140/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.5384 - val_loss: 0.6624
#
# Epoch 00140: loss improved from 0.49565 to 0.49509, saving model to bestmodel.h5
# Epoch 141/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4546 - val_loss: 0.6631
#
# Epoch 00141: loss improved from 0.49509 to 0.49424, saving model to bestmodel.h5
# Epoch 142/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4859 - val_loss: 0.6641
#
# Epoch 00142: loss improved from 0.49424 to 0.49340, saving model to bestmodel.h5
# Epoch 143/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5099 - val_loss: 0.6652
#
# Epoch 00143: loss improved from 0.49340 to 0.49277, saving model to bestmodel.h5
# Epoch 144/1000
# 2/2 [==============================] - 0s 37ms/step - loss: 0.5130 - val_loss: 0.6660
#
# Epoch 00144: loss improved from 0.49277 to 0.49204, saving model to bestmodel.h5
# Epoch 145/1000
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4834 - val_loss: 0.6663
#
# Epoch 00145: loss improved from 0.49204 to 0.49191, saving model to bestmodel.h5
# Epoch 146/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4683 - val_loss: 0.6661
#
# Epoch 00146: loss improved from 0.49191 to 0.49097, saving model to bestmodel.h5
# Epoch 147/1000
# 2/2 [==============================] - 0s 30ms/step - loss: 0.5105 - val_loss: 0.6664
#
# Epoch 00147: loss improved from 0.49097 to 0.49014, saving model to bestmodel.h5
# Epoch 148/1000
# 2/2 [==============================] - 0s 37ms/step - loss: 0.4853 - val_loss: 0.6667
#
# Epoch 00148: loss improved from 0.49014 to 0.48999, saving model to bestmodel.h5
# Epoch 149/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4528 - val_loss: 0.6685
#
# Epoch 00149: loss improved from 0.48999 to 0.48958, saving model to bestmodel.h5
# Epoch 150/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4671 - val_loss: 0.6700
#
# Epoch 00150: loss improved from 0.48958 to 0.48886, saving model to bestmodel.h5
# Epoch 151/1000
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4611 - val_loss: 0.6711
#
# Epoch 00151: loss improved from 0.48886 to 0.48828, saving model to bestmodel.h5
# Epoch 152/1000
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4950 - val_loss: 0.6722
#
# Epoch 00152: loss improved from 0.48828 to 0.48762, saving model to bestmodel.h5
# Epoch 153/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5192 - val_loss: 0.6733
#
# Epoch 00153: loss did not improve from 0.48762
# Epoch 154/1000
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4875 - val_loss: 0.6741
#
# Epoch 00154: loss improved from 0.48762 to 0.48692, saving model to bestmodel.h5
# Epoch 155/1000
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4978 - val_loss: 0.6750
#
# Epoch 00155: loss improved from 0.48692 to 0.48670, saving model to bestmodel.h5
# Epoch 156/1000
# 2/2 [==============================] - 0s 35ms/step - loss: 0.4691 - val_loss: 0.6757
#
# Epoch 00156: loss improved from 0.48670 to 0.48625, saving model to bestmodel.h5
# Epoch 157/1000
# 2/2 [==============================] - 0s 37ms/step - loss: 0.4897 - val_loss: 0.6770
#
# Epoch 00157: loss improved from 0.48625 to 0.48606, saving model to bestmodel.h5
# Epoch 158/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4735 - val_loss: 0.6776
#
# Epoch 00158: loss improved from 0.48606 to 0.48548, saving model to bestmodel.h5
# Epoch 159/1000
# 2/2 [==============================] - 0s 35ms/step - loss: 0.4918 - val_loss: 0.6785
#
# Epoch 00159: loss did not improve from 0.48548
# Epoch 160/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4720 - val_loss: 0.6784
#
# Epoch 00160: loss improved from 0.48548 to 0.48503, saving model to bestmodel.h5
# Epoch 161/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.4561 - val_loss: 0.6780
#
# Epoch 00161: loss improved from 0.48503 to 0.48483, saving model to bestmodel.h5
# Epoch 162/1000
# 2/2 [==============================] - 0s 32ms/step - loss: 0.5020 - val_loss: 0.6777
#
# Epoch 00162: loss improved from 0.48483 to 0.48432, saving model to bestmodel.h5
# Epoch 163/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4568 - val_loss: 0.6781
#
# Epoch 00163: loss improved from 0.48432 to 0.48408, saving model to bestmodel.h5
# Epoch 164/1000
# 2/2 [==============================] - 0s 36ms/step - loss: 0.4617 - val_loss: 0.6780
#
# Epoch 00164: loss did not improve from 0.48408
# Epoch 165/1000
# 2/2 [==============================] - 0s 43ms/step - loss: 0.4955 - val_loss: 0.6791
#
# Epoch 00165: loss improved from 0.48408 to 0.48356, saving model to bestmodel.h5
# Epoch 166/1000
# 2/2 [==============================] - 0s 40ms/step - loss: 0.4563 - val_loss: 0.6797
#
# Epoch 00166: loss improved from 0.48356 to 0.48317, saving model to bestmodel.h5
# Epoch 167/1000
# 2/2 [==============================] - 0s 31ms/step - loss: 0.4695 - val_loss: 0.6801
#
# Epoch 00167: loss improved from 0.48317 to 0.48301, saving model to bestmodel.h5
# Epoch 168/1000
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4912 - val_loss: 0.6794
#
# Epoch 00168: loss did not improve from 0.48301
# Epoch 169/1000
# 2/2 [==============================] - 0s 40ms/step - loss: 0.4437 - val_loss: 0.6798
#
# Epoch 00169: loss improved from 0.48301 to 0.48234, saving model to bestmodel.h5
# Epoch 170/1000
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4732 - val_loss: 0.6797
#
# Epoch 00170: loss improved from 0.48234 to 0.48198, saving model to bestmodel.h5
# Epoch 171/1000
# 2/2 [==============================] - 0s 35ms/step - loss: 0.5059 - val_loss: 0.6796
#
# Epoch 00171: loss improved from 0.48198 to 0.48173, saving model to bestmodel.h5
# Epoch 172/1000
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4938 - val_loss: 0.6797
#
# Epoch 00172: loss improved from 0.48173 to 0.48154, saving model to bestmodel.h5
# Restoring model weights from the end of the best epoch.
# Epoch 00172: early stopping

# %%
ridingModel = load_model('/content/bestmodel.h5')

# %%
train_predict = [scaler_y.inverse_transform(ridingModel.predict(x_train_sc))[i][0] for i in range(y_train_sc.shape[0])]
train_act = [scaler_y.inverse_transform(y_train_sc)[i][0] for i in range(y_train_sc.shape[0])]
test_predict= [scaler_y.inverse_transform(ridingModel.predict(x_test_sc))[i][0] for i in range(y_test_sc.shape[0])]
test_act = [scaler_y.inverse_transform(y_test_sc)[i][0] for i in range(y_test_sc.shape[0])]

# %%
d1 = {"actual train":train_act,
      "predicted traain": train_predict}
d2 = {"actual test": test_act,
      "predicted test":test_predict}
datatrain = pd.DataFrame(data=d1)
datatest= pd.DataFrame(data=d2)

# %%
meantrain =[abs(train_act[i]-train_predict[i])/train_act[i] for i in range(len(train_act))]
meantest = x =[abs(test_act[i]-test_predict[i])/test_act[i] for i in range(len(test_act))]
print(f"mean absolute error for training is {round(np.mean(meantrain)*100,ndigits=1)}%")
print(f"mean absolute error for test is {round(np.mean(meantest)*100,ndigits=1)}%")
# Out:
# mean absolute error for training is 11.8%
# mean absolute error for test is 18.4%

# %%
trainloss = hist.history['loss'] 
testloss = hist.history['val_loss']
plt.style.use('ggplot')
plt.figure(figsize=(20, 7))
plt.plot(trainloss,'r-',label='Training MSE')
plt.plot(testloss,'b-',label='Test MSE')

plt.legend()

# %%
plt.style.use('ggplot')
plt.figure(figsize=(20, 7))
plt.plot(test_act, label="True value")
plt.plot(test_predict, label="Predicted value")
plt.legend()

# %%
plt.style.use('ggplot')
plt.figure(figsize=(20, 7))
plt.plot(train_act, label="True value")
plt.plot(train_predict, label="Predicted value")
plt.legend()
